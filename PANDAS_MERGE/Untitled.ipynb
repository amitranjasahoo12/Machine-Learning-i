# %%
import pandas as pd

# %%
df1=pd.read_excel("Book1.xlsx")
df2=pd.read_excel("book2.xlsx")

# %%
df1
# Out:
#        Name     a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     nasik     2  23.0  22.00     0.00      23.75       0.43      24.00
# 1    sukesh     3  45.0  23.00   250.00      22.67       0.94      24.00
# 2     badal     4  56.0  43.00   500.00      21.33       0.47      24.00
# 3    naresh     5  76.0  32.00   750.00        NaN       0.00      24.00
# 4      sily     6  87.0  12.00  1000.00      23.00       0.71      23.75
# 5      babi    78  98.0  45.00  1250.00      24.33       0.47      24.00
# 6      baby     9  23.0  56.00  1500.00      23.75       1.09      24.25
# 7    kunmun  1750   NaN   0.43    24.00       0.00      24.75       0.43
# 8     namit  2000   NaN   0.43    24.50       0.50      25.75       0.83
# 9       tap  2250   NaN   0.71    24.25       0.43      25.75       1.30
# 10   naresh  2500   NaN   0.87    24.25        NaN      25.00       1.00
# 11   sillli  2750   NaN   1.30    24.75        NaN      25.00       1.00
# ...

# %%
df2
# Out:
#       Name target
# 0    nasik    NaN
# 1   sukesh   flag
# 2    badal    NaN
# 3   naresh    NaN
# 4     sily    NaN
# 5     babi   flag
# 6     baby    NaN
# 7   kunmun    NaN
# 8    namit    NaN
# 9      tap   flag
# 10  naresh    NaN
# 11  sillli    NaN
# 12    nisi    NaN
# 13   happy    NaN
# 14   dixit   flag
# 15   kumar    NaN
# 16  suresh   flag

# %%
ages = pd.Series([22, 35, 58], name="Age")
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df1[df1["cd"].isin([250, 28.75])] #I’m interested in
# Out:
#       Name     a     b      c      cd  avg_rss12  var_rss12  avg_rss13  \
# 1   sukesh     3  45.0  23.00  250.00      22.67       0.94      24.00
# 21     dig  5250  23.0  -3.37   28.75       4.03      31.75       1.79
#
#     var_rss13  avg_rss23  var_rss23
# 1        0.00      24.67       0.94
# 21       4.03      31.75       1.79

# %%
df1[(df1["cd"] == 250.00) | (df1["cd"] == 28.75)]
# Out:
#       Name     a     b      c      cd  avg_rss12  var_rss12  avg_rss13  \
# 1   sukesh     3  45.0  23.00  250.00      22.67       0.94      24.00
# 21     dig  5250  23.0  -3.37   28.75       4.03      31.75       1.79
#
#     var_rss13  avg_rss23  var_rss23
# 1        0.00      24.67       0.94
# 21       4.03      31.75       1.79

# %%
pd.merge(df1,df2,on="Name",how='inner').duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool

# %%
pd.merge(df1,df2,on="Name",how='outer').duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# dtype: bool

# %%
s1 = pd.Series(['a', 'b'])
s2 = pd.Series(['c', 'd'])

# %%
pd.concat([df1,df2],axis=1,join='outer')
# Out:
#        Name     a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     nasik     2  23.0  22.00     0.00      23.75       0.43      24.00
# 1    sukesh     3  45.0  23.00   250.00      22.67       0.94      24.00
# 2     badal     4  56.0  43.00   500.00      21.33       0.47      24.00
# 3    naresh     5  76.0  32.00   750.00        NaN       0.00      24.00
# 4      sily     6  87.0  12.00  1000.00      23.00       0.71      23.75
# 5      babi    78  98.0  45.00  1250.00      24.33       0.47      24.00
# 6      baby     9  23.0  56.00  1500.00      23.75       1.09      24.25
# 7    kunmun  1750   NaN   0.43    24.00       0.00      24.75       0.43
# 8     namit  2000   NaN   0.43    24.50       0.50      25.75       0.83
# 9       tap  2250   NaN   0.71    24.25       0.43      25.75       1.30
# 10   naresh  2500   NaN   0.87    24.25        NaN      25.00       1.00
# 11   sillli  2750   NaN   1.30    24.75        NaN      25.00       1.00
# ...

# %%
lst=[1,2,3,4,"amit","sahoo"]
print(lst)
print(lst[4])
lst[4]=5454
print(lst[4])
# Out:
# [1, 2, 3, 4, 'amit', 'sahoo']
# amit
# 5454

# %%
lst
# Out:
# [1, 2, 3, 4, 5454, 'sahoo']

# %%
kst=[1,2,3,4,"amit","sahoo"]

# %%
tu=tuple(kst)

# %%
tu
# Out:
# (1, 2, 3, 4, 'amit', 'sahoo')

# %%
print(tu)
print(tu[4])
# Out:
# (1, 2, 3, 4, 'amit', 'sahoo')
# amit

# %%
lst[4]=5454
print(lst[4])
# Out:
# 5454

# %%
lst
# Out:
# [1, 2, 3, 4, 5454, 'sahoo']

# %%
tu
# Out:
# (1, 2, 3, 4, 'amit', 'sahoo')

# %%
tu[0]
# Out:
# 1
