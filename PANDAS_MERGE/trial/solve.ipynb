# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_excel("Book.xlsx")
df2=pd.read_excel("boo.xlsx")

# %%
df1
# Out:
#        Name   a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     nasik   1  23.0  22.00     0.00      23.75       0.43      24.00
# 1    sukesh   2  45.0  23.00   250.00      22.67       0.94      24.00
# 2    sukesh   3  45.0  23.00   250.00      22.67       0.94      24.00
# 3     badal   4  56.0  43.00   500.00      21.33       0.47      24.00
# 4    naresh   5  76.0  32.00   750.00        NaN       0.00      24.00
# 5      sily   6  87.0  12.00  1000.00      23.00       0.71      23.75
# 6      babi   7  98.0  45.00  1250.00      24.33       0.47      24.00
# 7      babi   8  98.0  45.00  1250.00      24.33       0.47      24.00
# 8      babi   9  98.0  45.00  1250.00      24.33       0.47      24.00
# 9      baby  10  23.0  56.00  1500.00      23.75       1.09      24.25
# 10   kunmun  11   NaN   0.43    24.00       0.00      24.75       0.43
# 11    namit  12   NaN   0.43    24.50       0.50      25.75       0.83
# ...

# %%
df1.shape
# Out:
# (27, 11)

# %%
df2
# Out:
#       Name target
# 0    nasik    NaN
# 1   sukesh   flag
# 2    badal    NaN
# 3   naresh    NaN
# 4     sily    NaN
# 5     babi   flag
# 6     baby    NaN
# 7   kunmun    NaN
# 8    namit    NaN
# 9      tap   flag
# 10  naresh    NaN
# 11  sillli    NaN
# 12    nisi    NaN
# 13   happy    NaN
# 14   dixit   flag
# 15   kumar    NaN
# 16  suresh   flag

# %%
df2.shape
# Out:
# (17, 2)

# %%
df=pd.merge(df1,df2,on="Name",how='left')
df
# Out:
#        Name   a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     nasik   1  23.0  22.00     0.00      23.75       0.43      24.00
# 1    sukesh   2  45.0  23.00   250.00      22.67       0.94      24.00
# 2    sukesh   3  45.0  23.00   250.00      22.67       0.94      24.00
# 3     badal   4  56.0  43.00   500.00      21.33       0.47      24.00
# 4    naresh   5  76.0  32.00   750.00        NaN       0.00      24.00
# 5    naresh   5  76.0  32.00   750.00        NaN       0.00      24.00
# 6      sily   6  87.0  12.00  1000.00      23.00       0.71      23.75
# 7      babi   7  98.0  45.00  1250.00      24.33       0.47      24.00
# 8      babi   8  98.0  45.00  1250.00      24.33       0.47      24.00
# 9      babi   9  98.0  45.00  1250.00      24.33       0.47      24.00
# 10     baby  10  23.0  56.00  1500.00      23.75       1.09      24.25
# 11   kunmun  11   NaN   0.43    24.00       0.00      24.75       0.43
# ...

# %%
df.shape
# Out:
# (28, 12)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# dtype: bool

# %%
df.iloc[4:6]
# Out:
#      Name  a     b     c     cd  avg_rss12  var_rss12  avg_rss13  var_rss13  \
# 4  naresh  5  76.0  32.0  750.0        NaN        0.0       24.0        0.0
# 5  naresh  5  76.0  32.0  750.0        NaN        0.0       24.0        0.0
#
#    avg_rss23  var_rss23 target
# 4      25.25       1.09    NaN
# 5      25.25       1.09    NaN

# %% [markdown]
# ## when i merge my data set df1 and df2 df.iloc[4:6] these row print duplicate:

# %%
df.drop_duplicates(inplace=True) 
df
# Out:
#        Name   a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     nasik   1  23.0  22.00     0.00      23.75       0.43      24.00
# 1    sukesh   2  45.0  23.00   250.00      22.67       0.94      24.00
# 2    sukesh   3  45.0  23.00   250.00      22.67       0.94      24.00
# 3     badal   4  56.0  43.00   500.00      21.33       0.47      24.00
# 4    naresh   5  76.0  32.00   750.00        NaN       0.00      24.00
# 6      sily   6  87.0  12.00  1000.00      23.00       0.71      23.75
# 7      babi   7  98.0  45.00  1250.00      24.33       0.47      24.00
# 8      babi   8  98.0  45.00  1250.00      24.33       0.47      24.00
# 9      babi   9  98.0  45.00  1250.00      24.33       0.47      24.00
# 10     baby  10  23.0  56.00  1500.00      23.75       1.09      24.25
# 11   kunmun  11   NaN   0.43    24.00       0.00      24.75       0.43
# 12    namit  12   NaN   0.43    24.50       0.50      25.75       0.83
# ...

# %%
df.shape
# Out:
# (27, 12)

# %%
df.isnull().sum()
# Out:
# Name          0
# a             0
# b             7
# c             0
# cd            1
# avg_rss12     6
# var_rss12     0
# avg_rss13     0
# var_rss13     3
# avg_rss23     0
# var_rss23     3
# target       17
# dtype: int64

# %%
df["target"].fillna("SILLIIIIII", inplace=True)
df
# Out:
#        Name   a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     nasik   1  23.0  22.00     0.00      23.75       0.43      24.00
# 1    sukesh   2  45.0  23.00   250.00      22.67       0.94      24.00
# 2    sukesh   3  45.0  23.00   250.00      22.67       0.94      24.00
# 3     badal   4  56.0  43.00   500.00      21.33       0.47      24.00
# 4    naresh   5  76.0  32.00   750.00        NaN       0.00      24.00
# 6      sily   6  87.0  12.00  1000.00      23.00       0.71      23.75
# 7      babi   7  98.0  45.00  1250.00      24.33       0.47      24.00
# 8      babi   8  98.0  45.00  1250.00      24.33       0.47      24.00
# 9      babi   9  98.0  45.00  1250.00      24.33       0.47      24.00
# 10     baby  10  23.0  56.00  1500.00      23.75       1.09      24.25
# 11   kunmun  11   NaN   0.43    24.00       0.00      24.75       0.43
# 12    namit  12   NaN   0.43    24.50       0.50      25.75       0.83
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# a            0
# b            7
# c            0
# cd           1
# avg_rss12    6
# var_rss12    0
# avg_rss13    0
# var_rss13    3
# avg_rss23    0
# var_rss23    3
# target       0
# dtype: int64

# %%
df.shape
# Out:
# (27, 12)

# %%
df.to_excel("ami.xlsx")

# %%
ab=pd.read_excel("ami.xlsx",index_col=0)
ab
# Out:
#        Name   a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     nasik   1  23.0  22.00     0.00      23.75       0.43      24.00
# 1    sukesh   2  45.0  23.00   250.00      22.67       0.94      24.00
# 2    sukesh   3  45.0  23.00   250.00      22.67       0.94      24.00
# 3     badal   4  56.0  43.00   500.00      21.33       0.47      24.00
# 4    naresh   5  76.0  32.00   750.00        NaN       0.00      24.00
# 6      sily   6  87.0  12.00  1000.00      23.00       0.71      23.75
# 7      babi   7  98.0  45.00  1250.00      24.33       0.47      24.00
# 8      babi   8  98.0  45.00  1250.00      24.33       0.47      24.00
# 9      babi   9  98.0  45.00  1250.00      24.33       0.47      24.00
# 10     baby  10  23.0  56.00  1500.00      23.75       1.09      24.25
# 11   kunmun  11   NaN   0.43    24.00       0.00      24.75       0.43
# 12    namit  12   NaN   0.43    24.50       0.50      25.75       0.83
# ...

# %%
ab.isnull().sum()
# Out:
# Name         0
# a            0
# b            7
# c            0
# cd           1
# avg_rss12    6
# var_rss12    0
# avg_rss13    0
# var_rss13    3
# avg_rss23    0
# var_rss23    3
# target       0
# dtype: int64

# %%
ab.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# dtype: bool
